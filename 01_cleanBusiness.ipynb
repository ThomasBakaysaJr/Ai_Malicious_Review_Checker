# %%
import ast
import json
import random
import time

import autopep8
import numpy as np
import pandas as pd
from IPython.display import display
from pandas.api.types import is_numeric_dtype
from sklearn.preprocessing import LabelEncoder

# do get rid of annoying warnings
pd.set_option('future.no_silent_downcasting', True)

# %%
# global, for the print statements
verbose = True

# this should probably be on a seperate cell so I don't constantly reload the dataframes
fDefPath = 'reviews/yelpReviews/yelp_academic_dataset_'
# constants so I don't have to keep changing names
BS = 'business'
CH = 'checkin'
TI = 'tip'
RW = 'review'
US = 'user'

# subsets of what i care about
bssub = ['business_id', 'postal_code',
         'review_count', 'attributes', 'categories']
ussub = ['user_id', 'review_count', 'yelping_since']
rwsub = ['user_id', 'business_id', 'stars', 'text', 'date']

# constants for the file path
bspath = f'{fDefPath}{BS}.json'
chpath = f'{fDefPath}{CH}.json'
tipath = f'{fDefPath}{TI}.json'
rwpath = f'{fDefPath}{RW}.json'
uspath = f'{fDefPath}{US}.json'

# %%
# load the datasets
bsdf = pd.read_json(bspath, lines=True)
# take only what we want
bsdf = bsdf[bssub]

# %%
# create a manual dictionary for now
category_map = {
    # removed food, too broad, was catching grocery stores
    'restaurants': {'restaurants', 'sandwiches', 'american (new)', 'american (traditional)', 'pizza', 'bakeries', 'desserts', 'cafes', 'breakfast & brunch'},
    'retail': {'shopping', 'home & garden', 'fashion', 'real estate', 'grocery', 'department stores', 'electronics', 'toys'},
    'beauty': {'beauty & spas', 'hair salons', 'nail salons', 'massage', 'skin care', 'makeup artists'},
    'auto': {'automotive', 'auto repair'},
    'services': {'home services', 'local services', 'event planning & services'},
    'fitness': {'active life', 'fitness & instruction', 'gyms', 'yoga', 'martial arts'},
    'health': {'health & medical', 'doctors', 'dentists'},
    'pets': {'veterinarians', 'pet services', 'pets'},
    'nightlife': {'nightlife', 'bars', 'lounges', 'dance clubs', 'karaoke'},
    'travel': {'hotels & travel', 'hotels', 'tours'},
    'religious': {'religious organizations', 'synagogues'},
    'entertainment': {'festivals', 'arts & entertainment', 'television', 'mass media', 'museums', 'music venues', 'cinema', 'theaters'},
    'finance': {'banks & credit unions', 'financial services'},
    'legal': {'dui law', 'lawyers'},
    'government': {'public services & government', 'libraries'},
    'education': {'education'},
    'professional services': {'employment agencies', 'professional services'}
}

# %%
def matchBroadCategory(cat_list):
    for broad_cat, keywords in category_map.items():
        if any(cat in keywords for cat in cat_list):
            return broad_cat
    return "other"


# expand categories so we can then sort them into broader categories
bsdf = bsdf.dropna(subset=['categories', 'attributes']).copy()
bsdf['categories'] = bsdf['categories'].str.lower()
bsdf.loc[:, "categoryList"] = bsdf.loc[:, "categories"].str.split(", ")

# Flatten and count unique categories
allCategories = bsdf["categoryList"].explode().str.lower()
categoryCounts = allCategories.value_counts()

# Preview common categories
# print(categoryCounts.head(50))

bsdf["broadCategory"] = bsdf["categoryList"].apply(matchBroadCategory)

# %%
# put this into a csv so i can look at them better, only if verbose is True
if verbose:
    fileName = 'files/categorized.csv'
    bsdf[['categoryList', 'broadCategory']].to_csv(fileName)

# %%
# now I'm going to process the attributes in the business json
attDf = bsdf.dropna(subset=['attributes']).copy()

# %%
baseDf = bsdf[['business_id', 'attributes']].copy()
attDf = baseDf.attributes
# print(attDf.head())
attDf = pd.json_normalize(attDf, sep='_')

# normalize converts nested dictionaries into strings,
# convert it back into a dictionary
for col in attDf.columns:
    if attDf[col].apply(lambda x: isinstance(x, str) and x.strip().startswith('{')).any():
        attDf[col] = attDf[col].apply(
            lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Find columns with nested dicts
nested_cols = [col for col in attDf.columns if isinstance(
    attDf.dropna(subset=[col])[col].iloc[0], dict)]

# Flatten each nested dict into new columns
for col in nested_cols:
    nested_df = pd.json_normalize(attDf[col])
    nested_df.columns = [f"{col}_{subcol}" for subcol in nested_df.columns]
    attDf = attDf.drop(columns=[col]).join(nested_df)

# %%
# merge attributes back with their business_id
# drop old attribute column
if len(baseDf.columns) > 1:
    baseDf = baseDf.drop(['attributes'], axis=1)

# remove index to make sure they line up
baseDf = baseDf.reset_index(drop=True)
attDf = attDf.reset_index(drop=True)
# merge
mergedDf = pd.concat([baseDf, attDf], axis=1)
if verbose:
    print(mergedDf.head())
# Out:
#               business_id ByAppointmentOnly BusinessAcceptsCreditCards  \
# 0  Pns2l4eNsfO8kk83dixA6A              True                        NaN
# 1  mpf3x-BjTdTEA3yCZrAYPw               NaN                       True
# 2  tUFrWirKiKi_TAnsVWINQQ             False                       True
# 3  MTSW4McQd7CbVtyjqoe9mw             False                      False
# 4  mWMc6_wTdE0EUBKIGXDVfA               NaN                       True
#
#   BikeParking RestaurantsPriceRange2 CoatCheck RestaurantsTakeOut  \
# 0         NaN                    NaN       NaN                NaN
# 1         NaN                    NaN       NaN                NaN
# 2        True                      2     False              False
# 3        True                      1       NaN               True
# 4        True                    NaN       NaN               True
#
#   RestaurantsDelivery Caters     WiFi  ... HairSpecializesIn_kids  \
# 0                 NaN    NaN      NaN  ...                    NaN
# 1                 NaN    NaN      NaN  ...                    NaN
# 2               False  False    u'no'  ...                    NaN
# 3               False   True  u'free'  ...                    NaN
# 4                 NaN  False      NaN  ...                    NaN
#
#   HairSpecializesIn_perms HairSpecializesIn_asian  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   DietaryRestrictions_dairy-free DietaryRestrictions_gluten-free  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   DietaryRestrictions_vegan DietaryRestrictions_kosher  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#   DietaryRestrictions_halal DietaryRestrictions_soy-free  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#   DietaryRestrictions_vegetarian
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 82 columns]

# %%
# write at attributes normalized dataframe and the merged dataframe for
# easier manual checking (they're so long they don't fit in print statements)
if verbose:
    attDf.to_csv('files/att.csv')
    mergedDf.to_csv('files/mergedAtt.csv')

# %%
# doesn't manipulate data, just for checking. Will do nothing if verbose == False
if verbose:
    # check to make sure the business_id was lining up
    indices = list(range(len(baseDf)))
    random.shuffle(indices)
    # compare 15 random rows, using business_is as a common index
    lookat = indices[:15]

    # probably a cleaner way to do this, but oh well
    for ind in lookat:
        bsid = baseDf.iloc[ind]['business_id']
        mgid = mergedDf.iloc[ind]['business_id']
        bsAtt = list(bsdf.loc[bsdf['business_id'] == bsid]['attributes'])
        mdAtt = mergedDf.loc[mergedDf['business_id']
                             == mgid].drop(['business_id'], axis=1)
        mdAtt = mdAtt.dropna(axis=1)
        print(f' {bsid} : {mgid}')
        print(f'base frame att :\n {bsAtt} \n merged frame att: \n {mdAtt} ')
# Out:
#  HPj9nZqVUeifCrN3lvH0Iw : HPj9nZqVUeifCrN3lvH0Iw
# base frame att :
#  [{'GoodForKids': 'True', 'BikeParking': 'False', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", 'ByAppointmentOnly': 'True', 'BusinessAcceptsCreditCards': 'True', 'RestaurantsPriceRange2': '2'}]
#  merged frame att:
#        ByAppointmentOnly BusinessAcceptsCreditCards BikeParking  \
# 54286              True                       True       False
#
#       RestaurantsPriceRange2 GoodForKids BusinessParking_garage  \
# 54286                      2        True                  False
#
#       BusinessParking_street BusinessParking_validated BusinessParking_lot  \
# 54286                  False                     False                True
#
#       BusinessParking_valet
# 54286                 False
#  ueLgPhdg24-BwXuP-41gew : ueLgPhdg24-BwXuP-41gew
# base frame att :
#  [{'RestaurantsReservations': 'False', 'BusinessAcceptsCreditCards': 'True', 'HasTV': 'False', 'RestaurantsGoodForGroups': 'True', 'Caters': 'False', 'OutdoorSeating': 'False', 'RestaurantsTakeOut': 'True', 'Alcohol': "u'beer_and_wine'", 'RestaurantsPriceRange2': '2', 'RestaurantsAttire': "u'casual'", 'BikeParking': 'False', 'NoiseLevel': "u'average'", 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}", 'BYOB': 'False', 'WheelchairAccessible': 'True', 'GoodForKids': 'True', 'RestaurantsTableService': 'True', 'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': None, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}", 'Corkage': 'False', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", 'RestaurantsDelivery': 'True', 'BusinessAcceptsBitcoin': 'False', 'HappyHour': 'True', 'DogsAllowed': 'False', 'WiFi': "u'free'"}]
#  merged frame att:
#         BusinessAcceptsCreditCards BikeParking RestaurantsPriceRange2  \
# 102991                       True       False                      2
#
#        RestaurantsTakeOut RestaurantsDelivery Caters     WiFi  \
# 102991               True                True  False  u'free'
#
#        WheelchairAccessible HappyHour OutdoorSeating  ... Ambience_classy  \
# 102991                 True      True          False  ...           False
#
#        Ambience_trendy Ambience_upscale Ambience_casual GoodForMeal_dessert  \
# 102991           False            False            True               False
#
#        GoodForMeal_latenight GoodForMeal_lunch GoodForMeal_dinner  \
# 102991                 False             False               True
#
#        GoodForMeal_brunch GoodForMeal_breakfast
# 102991              False                 False
#
# [1 rows x 41 columns]
#  sYWl8GUvtCJFSYEBA58zdQ : sYWl8GUvtCJFSYEBA58zdQ
# base frame att :
#  [{'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}", 'ByAppointmentOnly': 'False', 'BusinessAcceptsCreditCards': 'False', 'WheelchairAccessible': 'True', 'BusinessAcceptsBitcoin': 'False', 'BikeParking': 'True'}]
#  merged frame att:
#        ByAppointmentOnly BusinessAcceptsCreditCards BikeParking  \
# 36584             False                      False        True
#
#       WheelchairAccessible BusinessAcceptsBitcoin BusinessParking_garage  \
# 36584                 True                  False                  False
#
#       BusinessParking_street BusinessParking_validated BusinessParking_lot  \
# 36584                   True                     False                True
#
#       BusinessParking_valet
# 36584                 False
#  qc9kW29jvA7jtjGMQPjykA : qc9kW29jvA7jtjGMQPjykA
# base frame att :
#  [{'BusinessAcceptsCreditCards': 'True', 'RestaurantsTakeOut': 'True', 'RestaurantsDelivery': 'False', 'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}", 'HasTV': 'False', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': True}", 'WiFi': "'no'", 'BikeParking': 'True', 'RestaurantsReservations': 'False', 'GoodForKids': 'False', 'HappyHour': 'True', 'BusinessAcceptsBitcoin': 'False', 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}", 'Caters': 'True', 'NoiseLevel': "u'loud'", 'RestaurantsPriceRange2': '2', 'RestaurantsTableService': 'False', 'RestaurantsGoodForGroups': 'True', 'Alcohol': "u'beer_and_wine'", 'OutdoorSeating': 'True', 'DogsAllowed': 'False', 'RestaurantsAttire': "'casual'"}]
#  merged frame att:
#        BusinessAcceptsCreditCards BikeParking RestaurantsPriceRange2  \
# 84820                       True        True                      2
#
#       RestaurantsTakeOut RestaurantsDelivery Caters  WiFi HappyHour  \
# 84820               True               False   True  'no'      True
#
#       OutdoorSeating  HasTV  ... Ambience_classy Ambience_trendy  \
# 84820           True  False  ...           False           False
#
#       Ambience_upscale Ambience_casual GoodForMeal_dessert  \
# 84820            False           False               False
#
#       GoodForMeal_latenight GoodForMeal_lunch GoodForMeal_dinner  \
# 84820                 False             False               True
#
#       GoodForMeal_brunch GoodForMeal_breakfast
# 84820              False                 False
#
# [1 rows x 39 columns]
#  vOe2KAgnb9dA6Np66clipw : vOe2KAgnb9dA6Np66clipw
# base frame att :
#  [{'ByAppointmentOnly': 'True', 'BusinessAcceptsCreditCards': 'True'}]
#  merged frame att:
#        ByAppointmentOnly BusinessAcceptsCreditCards
# 79375              True                       True
#  49Pz8HTwgtCv8L3JLWEUcw : 49Pz8HTwgtCv8L3JLWEUcw
# base frame att :
#  [{'BusinessAcceptsCreditCards': 'True'}]
#  merged frame att:
#        BusinessAcceptsCreditCards
# 24445                       True
#  e64AwwaK8zwczBLgHYZU0Q : e64AwwaK8zwczBLgHYZU0Q
# base frame att :
#  [{'GoodForKids': 'True', 'RestaurantsTableService': 'False', 'RestaurantsPriceRange2': '1', 'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}", 'Alcohol': "u'none'", 'WiFi': "u'no'", 'WheelchairAccessible': 'True', 'RestaurantsGoodForGroups': 'True', 'HasTV': 'True', 'DriveThru': 'True', 'NoiseLevel': "u'average'", 'OutdoorSeating': 'True', 'BikeParking': 'True', 'BusinessAcceptsCreditCards': 'True', 'RestaurantsReservations': 'False', 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': False}", 'DogsAllowed': 'False', 'RestaurantsTakeOut': 'True', 'RestaurantsAttire': "'casual'", 'BusinessParking': "{u'valet': False, u'garage': False, u'street': None, u'lot': True, u'validated': False}", 'RestaurantsDelivery': 'True', 'Caters': 'False'}]
#  merged frame att:
#        BusinessAcceptsCreditCards BikeParking RestaurantsPriceRange2  \
# 85988                       True        True                      1
#
#       RestaurantsTakeOut RestaurantsDelivery Caters   WiFi  \
# 85988               True                True  False  u'no'
#
#       WheelchairAccessible OutdoorSeating HasTV  ... Ambience_classy  \
# 85988                 True           True  True  ...           False
#
#       Ambience_trendy Ambience_upscale Ambience_casual GoodForMeal_dessert  \
# 85988           False            False            True               False
#
#       GoodForMeal_latenight GoodForMeal_lunch GoodForMeal_dinner  \
# 85988                 False              True              False
#
#       GoodForMeal_brunch GoodForMeal_breakfast
# 85988               True                 False
#
# [1 rows x 38 columns]
#  oiY16EMGfSfZharTPho76A : oiY16EMGfSfZharTPho76A
# base frame att :
#  [{'ByAppointmentOnly': 'False', 'BusinessAcceptsCreditCards': 'True', 'BikeParking': 'False', 'BusinessParking': 'None', 'RestaurantsPriceRange2': '2', 'DriveThru': 'True', 'RestaurantsTakeOut': 'True', 'RestaurantsDelivery': 'False'}]
#  merged frame att:
#        ByAppointmentOnly BusinessAcceptsCreditCards BikeParking  \
# 93142             False                       True       False
#
#       RestaurantsPriceRange2 RestaurantsTakeOut RestaurantsDelivery DriveThru
# 93142                      2               True               False      True
#  LlGHv3iqPsLc2clOwE8qug : LlGHv3iqPsLc2clOwE8qug
# base frame att :
#  [{'RestaurantsAttire': "u'casual'", 'BikeParking': 'True', 'RestaurantsPriceRange2': '2', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}", 'HasTV': 'True', 'RestaurantsGoodForGroups': 'True', 'BusinessAcceptsCreditCards': 'True', 'Caters': 'True', 'NoiseLevel': "u'average'", 'OutdoorSeating': 'True', 'RestaurantsReservations': 'False', 'WiFi': "'free'", 'RestaurantsTakeOut': 'True', 'GoodForKids': 'True', 'BusinessAcceptsBitcoin': 'False', 'Alcohol': "'full_bar'", 'GoodForDancing': 'False', 'BestNights': "{'monday': False, 'tuesday': True, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}", 'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': None, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}", 'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': None, 'live': False, 'video': False, 'karaoke': False}", 'GoodForMeal': "{'dessert': False, 'latenight': None, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}", 'RestaurantsDelivery': 'True'}]
#  merged frame att:
#        BusinessAcceptsCreditCards BikeParking RestaurantsPriceRange2  \
# 62176                       True        True                      2
#
#       RestaurantsTakeOut RestaurantsDelivery Caters    WiFi OutdoorSeating  \
# 62176               True                True   True  'free'           True
#
#       HasTV RestaurantsReservations  ... Music_live Music_video Music_karaoke  \
# 62176  True                   False  ...      False       False         False
#
#       BestNights_monday BestNights_tuesday BestNights_friday  \
# 62176             False               True             False
#
#       BestNights_wednesday BestNights_thursday BestNights_sunday  \
# 62176                False               False             False
#
#       BestNights_saturday
# 62176               False
#
# [1 rows x 48 columns]
#  RhivUbiAg0Muv0fxXLJk-A : RhivUbiAg0Muv0fxXLJk-A
# base frame att :
#  [{'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"}]
#  merged frame att:
#        BusinessParking_garage BusinessParking_street BusinessParking_validated  \
# 19926                  False                  False                     False
#
#       BusinessParking_lot BusinessParking_valet
# 19926               False                 False
#  sQ3Q5UAN3eStKnrxkK8E_A : sQ3Q5UAN3eStKnrxkK8E_A
# base frame att :
#  [{'RestaurantsTableService': 'False', 'OutdoorSeating': 'True', 'RestaurantsTakeOut': 'True', 'RestaurantsDelivery': 'False', 'WiFi': "u'free'"}]
#  merged frame att:
#         RestaurantsTakeOut RestaurantsDelivery     WiFi OutdoorSeating  \
# 130851               True               False  u'free'           True
#
#        RestaurantsTableService
# 130851                   False
#  Oh5Or6DRzWQqQ29riTtjVA : Oh5Or6DRzWQqQ29riTtjVA
# base frame att :
#  [{'ByAppointmentOnly': 'True', 'WheelchairAccessible': 'True', 'WiFi': "u'free'", 'BusinessAcceptsCreditCards': 'True'}]
#  merged frame att:
#        ByAppointmentOnly BusinessAcceptsCreditCards     WiFi  \
# 14036              True                       True  u'free'
#
#       WheelchairAccessible
# 14036                 True
#  rI3a37CLMBpI1aDUA6hMiQ : rI3a37CLMBpI1aDUA6hMiQ
# base frame att :
#  [{'RestaurantsTakeOut': 'True', 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}", 'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}", 'RestaurantsDelivery': 'True'}]
#  merged frame att:
#        RestaurantsTakeOut RestaurantsDelivery BusinessParking_garage  \
# 93231               True                True                  False
#
#       BusinessParking_street BusinessParking_validated BusinessParking_lot  \
# 93231                  False                     False               False
#
#       BusinessParking_valet Ambience_romantic Ambience_intimate  \
# 93231                 False             False             False
#
#       Ambience_touristy Ambience_hipster Ambience_divey Ambience_classy  \
# 93231             False            False          False           False
#
#       Ambience_trendy Ambience_upscale Ambience_casual
# 93231           False            False           False
#  OLkS4jfozQpUIUq0K6t_IQ : OLkS4jfozQpUIUq0K6t_IQ
# base frame att :
#  [{'RestaurantsGoodForGroups': 'True', 'BikeParking': 'True', 'RestaurantsTakeOut': 'True', 'Caters': 'True', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'True', 'NoiseLevel': "u'average'", 'RestaurantsAttire': "u'casual'", 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'RestaurantsPriceRange2': '1', 'Alcohol': "u'none'", 'HasTV': 'False', 'WiFi': "u'no'", 'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}", 'GoodForKids': 'True', 'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': False, 'breakfast': False}", 'RestaurantsDelivery': 'True', 'RestaurantsReservations': 'False'}]
#  merged frame att:
#        BusinessAcceptsCreditCards BikeParking RestaurantsPriceRange2  \
# 79481                       True        True                      1
#
#       RestaurantsTakeOut RestaurantsDelivery Caters   WiFi OutdoorSeating  \
# 79481               True                True   True  u'no'          False
#
#        HasTV RestaurantsReservations  ... Ambience_classy Ambience_trendy  \
# 79481  False                   False  ...           False           False
#
#       Ambience_upscale Ambience_casual GoodForMeal_dessert  \
# 79481            False            True               False
#
#       GoodForMeal_latenight GoodForMeal_lunch GoodForMeal_dinner  \
# 79481                 False              True              False
#
#       GoodForMeal_brunch GoodForMeal_breakfast
# 79481              False                 False
#
# [1 rows x 35 columns]
#  EtkNplbYROY-8nZz0YQbMQ : EtkNplbYROY-8nZz0YQbMQ
# base frame att :
#  [{'RestaurantsReservations': 'False', 'Caters': 'True', 'RestaurantsAttire': "u'casual'", 'OutdoorSeating': 'False', 'GoodForKids': 'True', 'RestaurantsDelivery': 'True', 'RestaurantsPriceRange2': '1', 'HasTV': 'True', 'RestaurantsTakeOut': 'True', 'BikeParking': 'True', 'RestaurantsGoodForGroups': 'True', 'Alcohol': "'none'", 'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}", 'BusinessAcceptsCreditCards': 'True', 'NoiseLevel': "'quiet'", 'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}"}]
#  merged frame att:
#       BusinessAcceptsCreditCards BikeParking RestaurantsPriceRange2  \
# 6012                       True        True                      1
#
#      RestaurantsTakeOut RestaurantsDelivery Caters OutdoorSeating HasTV  \
# 6012               True                True   True          False  True
#
#      RestaurantsReservations Alcohol  ... BusinessParking_valet  \
# 6012                   False  'none'  ...                 False
#
#      Ambience_romantic Ambience_intimate Ambience_touristy Ambience_hipster  \
# 6012             False             False             False            False
#
#      Ambience_divey Ambience_classy Ambience_trendy Ambience_upscale  \
# 6012          False           False           False            False
#
#      Ambience_casual
# 6012           False
#
# [1 rows x 28 columns]

# %%
# see which columns are binary and which are categorical
# replace 'None' and None with np.nan
# replace true and false with binary
mergedDf.replace(['None', 'none', 'NONE', None], np.nan, inplace=True)
mergedDf.replace(['True', True, 'False', False], [1, 1, 0, 0], inplace=True)
# convert dtypes so is_numeric_dtype works (they're all object dtype right now)_
mergedDf = mergedDf.convert_dtypes()

for col in mergedDf.columns:
    if col == 'business_id':
        continue

    if verbose:
        print(
            f'{col} has attributes is of type {mergedDf[col].dtype}: {mergedDf[col].unique()} : trimming . . .')

    if is_numeric_dtype(mergedDf[col].dtype):
        if verbose:
            print('is numeric')
    else:
        mergedDf[col] = mergedDf[col].str.strip('u\'')

    if verbose:
        print(f'{col} has attributes: {mergedDf[col].unique()}\n\n')
# Out:
# ByAppointmentOnly has attributes is of type Int64: <IntegerArray>
# [1, <NA>, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# ByAppointmentOnly has attributes: <IntegerArray>
# [1, <NA>, 0]
# Length: 3, dtype: Int64
#
#
# BusinessAcceptsCreditCards has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessAcceptsCreditCards has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# BikeParking has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BikeParking has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# RestaurantsPriceRange2 has attributes is of type string: <StringArray>
# [<NA>, '2', '1', '3', '4']
# Length: 5, dtype: string : trimming . . .
# RestaurantsPriceRange2 has attributes: <StringArray>
# [<NA>, '2', '1', '3', '4']
# Length: 5, dtype: string
#
#
# CoatCheck has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# CoatCheck has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# RestaurantsTakeOut has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# RestaurantsTakeOut has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# RestaurantsDelivery has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# RestaurantsDelivery has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Caters has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Caters has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# WiFi has attributes is of type string: <StringArray>
# [<NA>, "u'no'", "u'free'", "'free'", "'no'", "u'paid'", "'paid'"]
# Length: 7, dtype: string : trimming . . .
# WiFi has attributes: <StringArray>
# [<NA>, 'no', 'free', 'paid']
# Length: 4, dtype: string
#
#
# WheelchairAccessible has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# WheelchairAccessible has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# HappyHour has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HappyHour has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# OutdoorSeating has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# OutdoorSeating has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# HasTV has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HasTV has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# RestaurantsReservations has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# RestaurantsReservations has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# DogsAllowed has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DogsAllowed has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Alcohol has attributes is of type string: <StringArray>
# [              <NA>,          "u'none'",      "u'full_bar'",
#            "'none'",       "'full_bar'", "u'beer_and_wine'",
#   "'beer_and_wine'"]
# Length: 7, dtype: string : trimming . . .
# Alcohol has attributes: <StringArray>
# [<NA>, 'none', 'full_bar', 'beer_and_wine']
# Length: 4, dtype: string
#
#
# GoodForKids has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForKids has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# RestaurantsAttire has attributes is of type string: <StringArray>
# [<NA>, "u'casual'", "'casual'", "u'formal'", "'dressy'", "u'dressy'",
#  "'formal'"]
# Length: 7, dtype: string : trimming . . .
# RestaurantsAttire has attributes: <StringArray>
# [<NA>, 'casual', 'formal', 'dressy']
# Length: 4, dtype: string
#
#
# RestaurantsTableService has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# RestaurantsTableService has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# RestaurantsGoodForGroups has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# RestaurantsGoodForGroups has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# DriveThru has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DriveThru has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# NoiseLevel has attributes is of type string: <StringArray>
# [          <NA>,   "u'average'",     "u'quiet'",    "'average'",
#       "u'loud'", "u'very_loud'",      "'quiet'",  "'very_loud'",
#        "'loud'"]
# Length: 9, dtype: string : trimming . . .
# NoiseLevel has attributes: <StringArray>
# [<NA>, 'average', 'quiet', 'loud', 'very_loud']
# Length: 5, dtype: string
#
#
# BusinessAcceptsBitcoin has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessAcceptsBitcoin has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Smoking has attributes is of type string: <StringArray>
# [<NA>, "u'no'", "u'outdoor'", "u'yes'", "'outdoor'", "'no'"]
# Length: 6, dtype: string : trimming . . .
# Smoking has attributes: <StringArray>
# [<NA>, 'no', 'outdoor', 'yes']
# Length: 4, dtype: string
#
#
# GoodForDancing has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForDancing has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# AcceptsInsurance has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# AcceptsInsurance has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BYOB has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BYOB has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Corkage has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Corkage has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# BYOBCorkage has attributes is of type string: <StringArray>
# [            <NA>,     "'yes_free'",           "'no'",  "'yes_corkage'",
#     "u'yes_free'", "u'yes_corkage'",          "u'no'"]
# Length: 7, dtype: string : trimming . . .
# BYOBCorkage has attributes: <StringArray>
# [<NA>, 'yes_free', 'no', 'yes_corkage']
# Length: 4, dtype: string
#
#
# Open24Hours has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Open24Hours has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# RestaurantsCounterService has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# RestaurantsCounterService has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# AgesAllowed has attributes is of type string: <StringArray>
# [<NA>, "u'21plus'", "u'allages'", "u'18plus'"]
# Length: 4, dtype: string : trimming . . .
# AgesAllowed has attributes: <StringArray>
# [<NA>, '21plus', 'allages', '18plus']
# Length: 4, dtype: string
#
#
# BusinessParking_garage has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessParking_garage has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BusinessParking_street has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessParking_street has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BusinessParking_validated has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessParking_validated has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BusinessParking_lot has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessParking_lot has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# BusinessParking_valet has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BusinessParking_valet has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_romantic has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_romantic has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_intimate has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_intimate has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_touristy has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_touristy has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_hipster has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_hipster has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_divey has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_divey has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_classy has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_classy has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_trendy has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_trendy has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_upscale has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_upscale has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Ambience_casual has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Ambience_casual has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# GoodForMeal_dessert has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForMeal_dessert has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# GoodForMeal_latenight has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForMeal_latenight has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# GoodForMeal_lunch has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForMeal_lunch has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# GoodForMeal_dinner has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForMeal_dinner has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# GoodForMeal_brunch has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForMeal_brunch has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# GoodForMeal_breakfast has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# GoodForMeal_breakfast has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Music_dj has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Music_dj has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Music_background_music has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Music_background_music has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Music_no_music has attributes is of type Int64: <IntegerArray>
# [<NA>, 0]
# Length: 2, dtype: Int64 : trimming . . .
# is numeric
# Music_no_music has attributes: <IntegerArray>
# [<NA>, 0]
# Length: 2, dtype: Int64
#
#
# Music_jukebox has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Music_jukebox has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Music_live has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Music_live has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Music_video has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Music_video has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# Music_karaoke has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# Music_karaoke has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_monday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_monday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_tuesday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_tuesday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_friday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_friday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_wednesday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_wednesday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_thursday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_thursday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_sunday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_sunday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# BestNights_saturday has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# BestNights_saturday has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_straightperms has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_straightperms has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_coloring has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_coloring has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_extensions has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_extensions has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_africanamerican has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_africanamerican has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_curly has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_curly has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_kids has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_kids has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_perms has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_perms has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# HairSpecializesIn_asian has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# HairSpecializesIn_asian has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# DietaryRestrictions_dairy-free has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_dairy-free has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# DietaryRestrictions_gluten-free has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_gluten-free has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# DietaryRestrictions_vegan has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_vegan has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64
#
#
# DietaryRestrictions_kosher has attributes is of type Int64: <IntegerArray>
# [<NA>, 0]
# Length: 2, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_kosher has attributes: <IntegerArray>
# [<NA>, 0]
# Length: 2, dtype: Int64
#
#
# DietaryRestrictions_halal has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_halal has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# DietaryRestrictions_soy-free has attributes is of type Int64: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_soy-free has attributes: <IntegerArray>
# [<NA>, 0, 1]
# Length: 3, dtype: Int64
#
#
# DietaryRestrictions_vegetarian has attributes is of type Int64: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64 : trimming . . .
# is numeric
# DietaryRestrictions_vegetarian has attributes: <IntegerArray>
# [<NA>, 1, 0]
# Length: 3, dtype: Int64

# %%
# merged mergedDf (which is just business_id and  attributes(normalized) right now)
# with the broad categories
# drop unecessary columns (if they haven't been already)
if 'attributes' in bsdf.columns:
    bsdf = bsdf.drop(['attributes', 'categories', 'categoryList'], axis=1)

busCleanedDf = mergedDf.merge(bsdf, on='business_id', how='left')

label_encoder = LabelEncoder()
busCleanedDf['broadCategory'] = label_encoder.fit_transform(busCleanedDf['broadCategory'])

if verbose:
    pd.set_option('display.max_columns', None)
    display(busCleanedDf.head(3))
    pd.reset_option('display.max_columns')

# clean it up a bit, remove columns that are mostly empty
threshold = 0.9
busCleanedDf = busCleanedDf.loc[:, busCleanedDf.isnull().mean() < threshold]
busCleanedDf.to_csv('files/busCleaned.csv', index=False)
# Out:
#               business_id  ByAppointmentOnly  BusinessAcceptsCreditCards  \
# 0  Pns2l4eNsfO8kk83dixA6A                  1                        <NA>
# 1  mpf3x-BjTdTEA3yCZrAYPw               <NA>                           1
# 2  tUFrWirKiKi_TAnsVWINQQ                  0                           1
#
#    BikeParking RestaurantsPriceRange2  CoatCheck  RestaurantsTakeOut  \
# 0         <NA>                   <NA>       <NA>                <NA>
# 1         <NA>                   <NA>       <NA>                <NA>
# 2            1                      2          0                   0
#
#    RestaurantsDelivery  Caters  WiFi  WheelchairAccessible  HappyHour  \
# 0                 <NA>    <NA>  <NA>                  <NA>       <NA>
# 1                 <NA>    <NA>  <NA>                  <NA>       <NA>
# 2                    0       0    no                     1          0
#
#    OutdoorSeating  HasTV  RestaurantsReservations  DogsAllowed Alcohol  \
# 0            <NA>   <NA>                     <NA>         <NA>    <NA>
# 1            <NA>   <NA>                     <NA>         <NA>    <NA>
# 2               0      0                        0            0    <NA>
#
#    GoodForKids RestaurantsAttire  RestaurantsTableService  \
# 0         <NA>              <NA>                     <NA>
# 1         <NA>              <NA>                     <NA>
# 2         <NA>              <NA>                     <NA>
#
#    RestaurantsGoodForGroups  DriveThru NoiseLevel  BusinessAcceptsBitcoin  \
# 0                      <NA>       <NA>       <NA>                    <NA>
# 1                      <NA>       <NA>       <NA>                    <NA>
# 2                      <NA>       <NA>       <NA>                    <NA>
#
#   Smoking  GoodForDancing  AcceptsInsurance  BYOB  Corkage BYOBCorkage  \
# 0    <NA>            <NA>              <NA>  <NA>     <NA>        <NA>
# 1    <NA>            <NA>              <NA>  <NA>     <NA>        <NA>
# 2    <NA>            <NA>              <NA>  <NA>     <NA>        <NA>
#
#    Open24Hours  RestaurantsCounterService AgesAllowed  BusinessParking_garage  \
# 0         <NA>                       <NA>        <NA>                    <NA>
# 1         <NA>                       <NA>        <NA>                    <NA>
# 2         <NA>                       <NA>        <NA>                       0
#
#    BusinessParking_street  BusinessParking_validated  BusinessParking_lot  \
# 0                    <NA>                       <NA>                 <NA>
# 1                    <NA>                       <NA>                 <NA>
# 2                       0                          0                    1
#
#    BusinessParking_valet  Ambience_romantic  Ambience_intimate  \
# 0                   <NA>               <NA>               <NA>
# 1                   <NA>               <NA>               <NA>
# 2                      0               <NA>               <NA>
#
#    Ambience_touristy  Ambience_hipster  Ambience_divey  Ambience_classy  \
# 0               <NA>              <NA>            <NA>             <NA>
# 1               <NA>              <NA>            <NA>             <NA>
# 2               <NA>              <NA>            <NA>             <NA>
#
#    Ambience_trendy  Ambience_upscale  Ambience_casual  GoodForMeal_dessert  \
# 0             <NA>              <NA>             <NA>                 <NA>
# 1             <NA>              <NA>             <NA>                 <NA>
# 2             <NA>              <NA>             <NA>                 <NA>
#
#    GoodForMeal_latenight  GoodForMeal_lunch  GoodForMeal_dinner  \
# 0                   <NA>               <NA>                <NA>
# 1                   <NA>               <NA>                <NA>
# 2                   <NA>               <NA>                <NA>
#
#    GoodForMeal_brunch  GoodForMeal_breakfast  Music_dj  \
# 0                <NA>                   <NA>      <NA>
# 1                <NA>                   <NA>      <NA>
# 2                <NA>                   <NA>      <NA>
#
#    Music_background_music  Music_no_music  Music_jukebox  Music_live  \
# 0                    <NA>            <NA>           <NA>        <NA>
# 1                    <NA>            <NA>           <NA>        <NA>
# 2                    <NA>            <NA>           <NA>        <NA>
#
#    Music_video  Music_karaoke  BestNights_monday  BestNights_tuesday  \
# 0         <NA>           <NA>               <NA>                <NA>
# 1         <NA>           <NA>               <NA>                <NA>
# 2         <NA>           <NA>               <NA>                <NA>
#
#    BestNights_friday  BestNights_wednesday  BestNights_thursday  \
# 0               <NA>                  <NA>                 <NA>
# 1               <NA>                  <NA>                 <NA>
# 2               <NA>                  <NA>                 <NA>
#
#    BestNights_sunday  BestNights_saturday  HairSpecializesIn_straightperms  \
# 0               <NA>                 <NA>                             <NA>
# 1               <NA>                 <NA>                             <NA>
# 2               <NA>                 <NA>                             <NA>
#
#    HairSpecializesIn_coloring  HairSpecializesIn_extensions  \
# 0                        <NA>                          <NA>
# 1                        <NA>                          <NA>
# 2                        <NA>                          <NA>
#
#    HairSpecializesIn_africanamerican  HairSpecializesIn_curly  \
# 0                               <NA>                     <NA>
# 1                               <NA>                     <NA>
# 2                               <NA>                     <NA>
#
#    HairSpecializesIn_kids  HairSpecializesIn_perms  HairSpecializesIn_asian  \
# 0                    <NA>                     <NA>                     <NA>
# 1                    <NA>                     <NA>                     <NA>
# 2                    <NA>                     <NA>                     <NA>
#
#    DietaryRestrictions_dairy-free  DietaryRestrictions_gluten-free  \
# 0                            <NA>                             <NA>
# 1                            <NA>                             <NA>
# 2                            <NA>                             <NA>
#
#    DietaryRestrictions_vegan  DietaryRestrictions_kosher  \
# 0                       <NA>                        <NA>
# 1                       <NA>                        <NA>
# 2                       <NA>                        <NA>
#
#    DietaryRestrictions_halal  DietaryRestrictions_soy-free  \
# 0                       <NA>                          <NA>
# 1                       <NA>                          <NA>
# 2                       <NA>                          <NA>
#
#    DietaryRestrictions_vegetarian postal_code  review_count  broadCategory
# 0                            <NA>       93101             7              7
# 1                            <NA>       63123            15             16
# 2                            <NA>       85711            22             15
